# %%
import pandas as pd
df = pd.read_parquet('data/raw/energy_raw.parquet')
df.head(20)
# Out:
#              timestamp    location_id  latitude  solar_capacity_kw  \
# 0  2018-01-01 00:00:00  AU_Queensland     -27.5                250
# 1  2018-01-01 01:00:00  AU_Queensland     -27.5                250
# 2  2018-01-01 02:00:00  AU_Queensland     -27.5                250
# 3  2018-01-01 03:00:00  AU_Queensland     -27.5                250
# 4  2018-01-01 04:00:00  AU_Queensland     -27.5                250
# 5  2018-01-01 05:00:00  AU_Queensland     -27.5                250
# 6  2018-01-01 06:00:00  AU_Queensland     -27.5                250
# 7  2018-01-01 07:00:00  AU_Queensland     -27.5                250
# 8  2018-01-01 08:00:00  AU_Queensland     -27.5                250
# 9  2018-01-01 09:00:00  AU_Queensland     -27.5                250
# 10 2018-01-01 10:00:00  AU_Queensland     -27.5                250
# 11 2018-01-01 11:00:00  AU_Queensland     -27.5                250
# 12 2018-01-01 12:00:00  AU_Queensland     -27.5                250
# ...

# %%
df.shape
# Out:
# (525840, 13)
